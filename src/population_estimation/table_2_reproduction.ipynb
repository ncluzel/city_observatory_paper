# %%
import pandas as pd
import numpy as np
import itertools
import glob
import sys
import os

from models_generation_utils import *
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
filepath = '../../data/Observatory_paper_mendeley.xlsx'
# 'NH4', 'DCO', 'DBO', 'NTK', 'NGL', 'PT', 'MES'
QIj_vect = np.array([10.3, 120, 60, 12.6, 12.6, 1.2, 60])

# %% [markdown]
# ### SEV

# %%
wwtp = 'SEV'
raw_data = get_raw_data(wwtp, filepath)
obs_matrix, obs_matrix_CIL, obs_matrix_CIU = get_obs_matrix(wwtp, gather_CIs=True)
get_new_QIj_vect_and_CIs(obs_matrix)
# Out:
# NH4: 11.6  [10.3, 12.2]
# COD: 128.6 [119.7, 139.2]
# BOD: 55.1  [51.0, 58.4]
# TKN: 12.5  [11.9, 12.6]
# TP:  1.2   [1.1, 1.4]
# SS:  69.1  [60.1, 82.4]

# %% [markdown]
# ### MAV

# %%
wwtp = 'MAV'
raw_data = get_raw_data(wwtp, filepath)
obs_matrix, obs_matrix_CIL, obs_matrix_CIU = get_obs_matrix(wwtp, gather_CIs=True)
get_new_QIj_vect_and_CIs(obs_matrix)
# Out:
# NH4: 11.2  [9.8, 12.9]
# COD: 128.2 [113.6, 143.7]
# BOD: 53.9  [42.7, 65.6]
# TKN: 12.4  [11.8, 12.5]
# TP:  1.4   [1.2, 1.6]
# SS:  54.5  [46.2, 63.1]

# %% [markdown]
# ### CLICHY

# %%
wwtp = 'CLICHY'
raw_data = get_raw_data(wwtp, filepath)
obs_matrix, obs_matrix_CIL, obs_matrix_CIU = get_obs_matrix(wwtp, gather_CIs=True, limit_2020=False)
get_new_QIj_vect_and_CIs(obs_matrix)
# Out:
# NH4: 11.1  [10.1, 12.1]
# COD: 127.9 [113.2, 141.0]
# BOD: 50.1  [41.5, 57.0]
# TKN: 12.4  [11.8, 12.5]
# TP:  1.3   [1.2, 1.4]
# SS:  61.2  [54.6, 70.0]
